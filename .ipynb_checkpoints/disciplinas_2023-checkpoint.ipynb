# %% [markdown]
# # **Carregar tabela dados ingresso**

# %%
import pandas as pd
import os

try:
    # Caminho para o arquivo tabela_dados_ingresso_tratada.csv
    caminho_tabela_dados_ingresso_tratada = os.path.expanduser(
        '~/Área de Trabalho/Semestre 2024.2/Dados/Tabelas_Tratadas/tabela_dados_ingresso_tratada.csv'
    )

    # Verificar se o arquivo existe
    if os.path.exists(caminho_tabela_dados_ingresso_tratada):
        print("O arquivo foi encontrado. Carregando agora...")
        
        # Carregar a tabela tabela_dados_ingresso_tratada.csv
        tabela_dados_ingresso_tratada_df = pd.read_csv(caminho_tabela_dados_ingresso_tratada, low_memory=False)
        print("Tabela tabela_dados_ingresso_tratada.csv carregada com sucesso!")

        # Visualizar as últimas 10 linhas
        print("\nÚltimas 10 linhas da tabela tabela_dados_ingresso_tratada.csv:")
        print(tabela_dados_ingresso_tratada_df.tail(10))
    else:
        print(f"Arquivo não encontrado no caminho: {caminho_tabela_dados_ingresso_tratada}")

except Exception as e:
    print(f"Erro ao carregar ou visualizar a tabela tabela_dados_ingresso_tratada.csv: {e}")
# Out:
# O arquivo foi encontrado. Carregando agora...
# Tabela tabela_dados_ingresso_tratada.csv carregada com sucesso!
#
# Últimas 10 linhas da tabela tabela_dados_ingresso_tratada.csv:
#       MATRICULA TIPO_ADMISSAO  Unnamed: 2 TIPO_ENSINO_MEDIO  \
# 3751  123210971          SISU         NaN      DESCONHECIDA
# 3752  123210972          SISU         NaN      DESCONHECIDA
# 3753  123210973          SISU         NaN      DESCONHECIDA
# 3754  123210974          SISU         NaN      DESCONHECIDA
# 3755  123210975          SISU         NaN           PUBLICA
# 3756  123210976          SISU         NaN      DESCONHECIDA
# 3757  123210978          SISU         NaN      DESCONHECIDA
# 3758  123210980          SISU         NaN      DESCONHECIDA
# 3759  123210982          SISU         NaN           PUBLICA
# 3760  123211071    VESTIBULAR         NaN           PUBLICA
#
#      POLITICA_AFIRMATIVA_ALUNOS
# 3751                         L2
# 3752                         L2
# ...

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# Garantir que o estilo do Seaborn seja configurado
sns.set(style="whitegrid")

try:
    # Caminho para o arquivo tabela_dados_ingresso_tratada.csv
    caminho_tabela_dados_ingresso_tratada = os.path.expanduser(
        '~/Área de Trabalho/Semestre 2024.2/Dados/Tabelas_Tratadas/tabela_dados_ingresso_tratada.csv'
    )

    # Verificar se o arquivo existe
    if os.path.exists(caminho_tabela_dados_ingresso_tratada):
        print("O arquivo foi encontrado. Carregando agora...")
        
        # Carregar a tabela tabela_dados_ingresso_tratada.csv
        dados_ingresso_df = pd.read_csv(caminho_tabela_dados_ingresso_tratada, low_memory=False)
        print("Tabela tabela_dados_ingresso_tratada.csv carregada com sucesso!")

        # Visualizar as últimas 10 linhas
        print("\nÚltimas 10 linhas da tabela tabela_dados_ingresso_tratada.csv:")
        print(dados_ingresso_df.tail(10))

        # Identificar valores ausentes por coluna
        valores_ausentes = dados_ingresso_df.isnull().sum()
        valores_ausentes = valores_ausentes[valores_ausentes > 0]  # Filtrar apenas colunas com valores ausentes

        if valores_ausentes.empty:
            print("Nenhum valor ausente encontrado na tabela.")
        else:
            print("\nValores ausentes por coluna:")
            print(valores_ausentes)

            # Criar um gráfico para visualizar os valores ausentes
            plt.figure(figsize=(12, 6))
            sns.barplot(
                x=valores_ausentes.index,
                y=valores_ausentes.values,
                palette="viridis"
            )
            plt.title("Valores Ausentes por Coluna - Tabela Dados Ingresso", fontsize=16)
            plt.xlabel("Colunas", fontsize=12)
            plt.ylabel("Número de Valores Ausentes", fontsize=12)
            plt.xticks(rotation=90)
            plt.tight_layout()
            plt.grid(axis="y", linestyle="--", alpha=0.7)
            plt.show()
    else:
        print(f"Arquivo não encontrado no caminho: {caminho_tabela_dados_ingresso_tratada}")

except Exception as e:
    print(f"Erro ao carregar, tratar ou visualizar valores ausentes: {e}")
# Out:
# O arquivo foi encontrado. Carregando agora...
# Tabela tabela_dados_ingresso_tratada.csv carregada com sucesso!
#
# Últimas 10 linhas da tabela tabela_dados_ingresso_tratada.csv:
#       MATRICULA TIPO_ADMISSAO  Unnamed: 2 TIPO_ENSINO_MEDIO  \
# 3751  123210971          SISU         NaN      DESCONHECIDA
# 3752  123210972          SISU         NaN      DESCONHECIDA
# 3753  123210973          SISU         NaN      DESCONHECIDA
# 3754  123210974          SISU         NaN      DESCONHECIDA
# 3755  123210975          SISU         NaN           PUBLICA
# 3756  123210976          SISU         NaN      DESCONHECIDA
# 3757  123210978          SISU         NaN      DESCONHECIDA
# 3758  123210980          SISU         NaN      DESCONHECIDA
# 3759  123210982          SISU         NaN           PUBLICA
# 3760  123211071    VESTIBULAR         NaN           PUBLICA
#
#      POLITICA_AFIRMATIVA_ALUNOS
# 3751                         L2
# 3752                         L2
# ...
